# %%
import numpy as np
import yfinance as yf
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.dates as mdates
import IchimokuLibrary

import arch.bootstrap as ab

# %%
START = "2015-01-01"
END = "2025-01-01"
TICKER = "^N225"
TITLE = TICKER + " - " + (datetime.now()).strftime("%Y-%m-%d - %H:%M:%S")

# %%
data = yf.download(TICKER,start=START, end=END,multi_level_index=False)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data["Close"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
data.to_csv("Nikkei.csv")

# %%
data.describe()
# Out:
#               Close          High           Low          Open        Volume
# count   2445.000000   2445.000000   2445.000000   2445.000000  2.445000e+03
# mean   24831.935860  24967.355835  24687.412581  24831.967658  9.774327e+07
# std     6309.139196   6345.584550   6271.569740   6306.691791  4.041954e+07
# min    14952.019531  15323.950195  14864.009766  15094.709961  0.000000e+00
# 25%    20013.259766  20087.009766  19927.070312  20015.070312  6.810000e+07
# 50%    22823.259766  22922.800781  22728.060547  22849.910156  8.730000e+07
# 75%    28451.019531  28580.199219  28282.210938  28415.109375  1.208000e+08
# max    42224.019531  42426.769531  42102.460938  42343.718750  3.405000e+08
